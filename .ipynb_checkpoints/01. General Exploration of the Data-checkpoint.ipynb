# %% [markdown]
# <link rel="stylesheet" type="text/css" href="bootstrap.min.css">
#
# # Exploring the Data about Titanic Survival
#
# _Source: Kaggle.com_
# ***

# %% [markdown]
# ## Goal

# %% [markdown]
# The goal of this notebook is to study the data about the Titanic tragedy. The dataset was extracted from the Kaggle competition located at [https://www.kaggle.com/c/titanic](https://www.kaggle.com/c/titanic). Future work on this dataset will be done to predict individuals survival using different classification methods.

# %%
### Load necessary packages
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns
sns.set_style('whitegrid')
sns.set_context('poster')

from matplotlib import rcParams # Enhance plots

# %% [markdown]
# ## Loading and displaying the data

# %% [markdown]
# Load the data from the CSV file located in the same folder as this notebook.

# %%
df = pd.read_csv('./data/train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# This means we have 891 observations (in our study: passengers). For each observation, we have 12 features (information). Let's get the list of features:

# %%
# Get the attributes list and their types
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# As a recall, here are the attributes meanings from Kaggle:

# %% [markdown]
# ```
# VARIABLE DESCRIPTIONS:
# survival        Survival
#                 (0 = No; 1 = Yes)
# pclass          Passenger Class
#                 (1 = 1st; 2 = 2nd; 3 = 3rd)
# name            Name
# sex             Sex
# age             Age
# sibsp           Number of Siblings/Spouses Aboard
# parch           Number of Parents/Children Aboard
# ticket          Ticket Number
# fare            Passenger Fare
# cabin           Cabin
# embarked        Port of Embarkation
#                 (C = Cherbourg; Q = Queenstown; S = Southampton)
#
# SPECIAL NOTES:
# Pclass is a proxy for socio-economic status (SES)
#  1st ~ Upper; 2nd ~ Middle; 3rd ~ Lower
#
# Age is in Years; Fractional if Age less than One (1)
#  If the Age is Estimated, it is in the form xx.5
#
# With respect to the family relation variables (i.e. sibsp and parch)
# some relations were ignored.  The following are the definitions used
# for sibsp and parch.
#
# Sibling:  Brother, Sister, Stepbrother, or Stepsister of Passenger Aboard Titanic
# Spouse:   Husband or Wife of Passenger Aboard Titanic (Mistresses and Fiances Ignored)
# Parent:   Mother or Father of Passenger Aboard Titanic
# Child:    Son, Daughter, Stepson, or Stepdaughter of Passenger Aboard Titanic
#
# Other family relatives excluded from this study include cousins,
# nephews/nieces, aunts/uncles, and in-laws.  Some children travelled
# only with a nanny, therefore parch=0 for them.  As well, some
# travelled with very close friends or neighbors in a village, however,
# the definitions do not support such relations.
# ```

# %% [markdown]
# Get some meta information about the numerical attributes in the dataset:

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# First thing we can notice is that the count of the _ages_ attribute is lower that the length of the dataset (714/891) which means that ~20% of the passengers in the training dataset have missing age values.
#
# From the mean of _Survived_ attributes, it comes that the survival rate from this training dataset is about 38%, where the historical survival rate is about 32% (722 passengers survived out of 2224 passengers). Which means that the training dataset is quite representative of the full passengers of the Titanic. Unfortunately, we can't judge on the representativeness of the other provided parameters since we don't have other sources about the them.

# %% [markdown]
# ***
# ## Some analysis to understand the data and the context
#
# We will now generate some plots to have a better understanding of the data.

# %% [markdown]
# ***
# ### Studying survivors
#
# Let's first have a look at survivors.

# %%
survivors = df[df.Survived == 1]
survivors.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
age_ranges = np.arange(0, 90, 10)
survivors_per_age_range = [df[(df['Survived'] == 1) & (df['Age'] >= a) & (df['Age'] < a + 10)] for a in age_ranges]

# %% [markdown]
# Let's see the distribution of survivors among age ranges of 10 years:

# %%
len_survivors = [len(survivor) for survivor in survivors_per_age_range]

plt.bar(age_ranges, len_survivors, width = 9, alpha = 0.6)
plt.xlabel('Age of survivors')
plt.ylabel('Count')
plt.title('Count of survivors based on ages')
plt.show()

# %% [markdown]
# More information about the last bar chart, showing Sex of survivors:

# %%
len_survivors_women = [len(survivor[survivor.Sex == 'female']) for survivor in survivors_per_age_range]
len_survivors_men = [len(survivor[survivor.Sex == 'male']) for survivor in survivors_per_age_range]

p1 = plt.bar(age_ranges, len_survivors_women, width = 9, alpha = 0.6, color = 'r')
p2 = plt.bar(age_ranges, len_survivors_men, width = 9, alpha = 0.6, color = 'b', bottom = len_survivors_women)

plt.legend((p2, p1), ('Men', 'Women'))
plt.xlabel('Age of survivors')
plt.ylabel('Count')
plt.title('Count of survivors based on ages')
plt.show()

# %% [markdown]
# Same as before, but with embarkment information:

# %%
len_survivors_s = [len(survivor[survivor.Embarked == 'S']) for survivor in survivors_per_age_range]
len_survivors_c = [len(survivor[survivor.Embarked == 'C']) for survivor in survivors_per_age_range]
len_survivors_q = [len(survivor[survivor.Embarked == 'Q']) for survivor in survivors_per_age_range]

p1 = plt.bar(age_ranges, len_survivors_s, width = 9, alpha = 0.6, color = 'b')
p2 = plt.bar(age_ranges, len_survivors_c, width = 9, alpha = 0.6, color = 'r', bottom = len_survivors_s)
p3 = plt.bar(age_ranges, len_survivors_q, width = 9, alpha = 0.6, color = 'g', bottom = [sum(x) for x in zip(len_survivors_s, len_survivors_c)])

plt.legend((p1, p2, p3), ('Southampton', 'Cherbourg', 'Queenstown'))
plt.xlabel('Age of survivors')
plt.ylabel('Count')
plt.title('Count of survivors based on ages')
plt.show()

# %%
len_survivors_class_1 = [len(survivor[survivor.Pclass == 1]) for survivor in survivors_per_age_range]
len_survivors_class_2 = [len(survivor[survivor.Pclass == 2]) for survivor in survivors_per_age_range]
len_survivors_class_3 = [len(survivor[survivor.Pclass == 3]) for survivor in survivors_per_age_range]

p1 = plt.bar(age_ranges, len_survivors_class_1, width = 9, alpha = 0.6, color = 'b')
p2 = plt.bar(age_ranges, len_survivors_class_2, width = 9, alpha = 0.6, color = 'r', bottom = len_survivors_class_1)
p3 = plt.bar(age_ranges, len_survivors_class_3, width = 9, alpha = 0.6, color = 'g', bottom = [sum(x) for x in zip(len_survivors_class_1, len_survivors_class_2)])

plt.legend((p1, p2, p3), ('1st Class', '2nd Class', '3rd Class'))
plt.xlabel('Age of survivors')
plt.ylabel('Count')
plt.title('Count of survivors based on ages')
plt.show()

# %% [markdown]
# ***
# ### Survivors/Victims analysis
#
# The previous section studied only the survivors of the Titanic, which showed up some information about their demographics. We will now have a look at the survivors/victims demographic, which will show other useful information and give us a feeling of potential hidden patterns.

# %%
# Split the dataset as survivors/victims
survivors = df[df.Survived == 1]
victims = df[df.Survived == 0]

# %%
survivors.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
victims.head()
# Out:
#    PassengerId  Survived  Pclass                            Name   Sex   Age  \
# 0            1         0       3         Braund, Mr. Owen Harris  male  22.0
# 4            5         0       3        Allen, Mr. William Henry  male  35.0
# 5            6         0       3                Moran, Mr. James  male   NaN
# 6            7         0       1         McCarthy, Mr. Timothy J  male  54.0
# 7            8         0       3  Palsson, Master. Gosta Leonard  male   2.0
#
#    SibSp  Parch     Ticket     Fare Cabin Embarked
# 0      1      0  A/5 21171   7.2500   NaN        S
# 4      0      0     373450   8.0500   NaN        S
# 5      0      0     330877   8.4583   NaN        Q
# 6      0      0      17463  51.8625   E46        S
# 7      3      1     349909  21.0750   NaN        S

# %% [markdown]
# As we did previousely, we will start by comparing survivors and victims based on their ages. Remember that ~20% of the `age` attribute information are missing.

# %%
age_ranges = np.arange(0, 90, 10)
survivors_per_age_range = [df[(df['Survived'] == 1) & (df['Age'] >= a) & (df['Age'] < a + 10)] for a in age_ranges]
victims_per_age_range = [df[(df['Survived'] == 0) & (df['Age'] >= a) & (df['Age'] < a + 10)] for a in age_ranges]

len_survivors = [len(survivor) for survivor in survivors_per_age_range]
len_victims = [len(survivor) for survivor in victims_per_age_range]

# %%
p1 = plt.bar(age_ranges, len_survivors, width = 9, alpha = 0.6, color = 'b')
p2 = plt.bar(age_ranges, len_victims, width = 9, alpha = 0.6, color = 'r', bottom = len_survivors)

plt.legend((p2, p1), ('Victims', 'Survivors'))
plt.xlabel('Age of passengers')
plt.ylabel('Count')
plt.title('Count of survivors and victims based on ages')
plt.show()

# %% [markdown]
# Except for the 0-10 years old range, the total of victims for each age range is higher than the total of survivals, with a peak for the 20-30 years old range. This graph shows the influence of age in the survival.

# %% [markdown]
# Plotting the survival bar graph depending on the sex of passenger.

# %%
survivors_per_sex = [len(survivors[survivors.Sex == sex]) for sex in ['female', 'male']]
victims_per_sex = [len(victims[victims.Sex == sex]) for sex in ['female', 'male']]

p1 = plt.bar([0, 1], survivors_per_sex, color = 'b', alpha = 0.6)
p2 = plt.bar([0, 1], victims_per_sex, color = 'r', alpha = 0.6, bottom = survivors_per_sex)

plt.xticks([0.4, 1.4], ('Female', 'Male'))
plt.legend((p2, p1), ('Victims', 'Survivors'), loc = 'upper left')
plt.ylabel('Count')
plt.title('Count of survivors/victims based on Sex attribute')
plt.show()

# %% [markdown]
# This gives the information that women are more likely to survive than men in this kind of tragedy.
#
# Let's now do the same analysis with the passenger classes.

# %%
survivors_per_class = [len(survivors[survivors.Pclass == pclass]) for pclass in [1, 2, 3]]
victims_per_class = [len(victims[victims.Pclass == pclass]) for pclass in [1, 2, 3]]

p1 = plt.bar([0, 1, 2], survivors_per_class, alpha = 0.6, color = 'b')
p2 = plt.bar([0, 1, 2], victims_per_class, alpha = 0.6, color = 'r', bottom = survivors_per_class)

plt.xticks([0.4, 1.4, 2.4], ('1st Class', '2nd Class', '3rd Class'))
plt.legend((p2, p1), ('Victims', 'Survivors'), loc = 'upper left')
plt.ylabel('Count')
plt.title('Count of survivors/victims based on passenger class attribute')
plt.show()

# %% [markdown]
# The display of the passengers survival based on the travel fare is better visualized through scatterplotting.

# %%
survivors_ticket_fare = survivors.Fare
victims_ticket_fare = victims.Fare

plt.scatter(survivors_ticket_fare, np.ones(len(survivors_ticket_fare)), marker = 'o', color = 'green', alpha = 0.6)
plt.scatter(victims_ticket_fare, np.zeros(len(victims_ticket_fare)), marker = 'o', color = 'red', alpha = 0.6)
plt.xlabel('Ticket Fare')
plt.ylabel('0- Victim | 1- Survivor')
plt.title('Survivors/Victims based on ticket fare')
plt.show()

# %% [markdown]
# Difficult to say from the ticket fare who survived and who died. This was more clear from the passenger class and sex.

# %% [markdown]
# We will now scatter some plots showing other attributes.

# %%
plt.subplot(211)
plt.scatter(survivors_ticket_fare, survivors.Pclass, marker = 'o', color = 'green', alpha = 0.6)
plt.xlabel('Ticket fare')
plt.ylabel('Survivor Class')

plt.subplot(212)
plt.scatter(victims_ticket_fare, victims.Pclass, marker = 'o', color = 'red', alpha = 0.6)
plt.xlabel('Ticket fare')
plt.ylabel('Victim Class')

plt.show()

# %% [markdown]
# Still not relevant to visually predict passenger survival depending on the ticket fare and passenger class. Even if we can see that survivors of 3rd class passengers is lower that victims, this is best visualized using the previous bar chart.

# %% [markdown]
# ***
# ## Features Correlations
#
# Let's now have a look at features correlation to have an idea on variables (in)dependance.

# %%
df.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %% [markdown]
# Looking at the `Survived` feature, which represents the survival, we can say that it is more correlated to the passenger class `Pclass` feature and the ticket fare `Fare` feature.

# %% [markdown]
# We can see that the passenger sex is not represented in the correlation matrix, because `Sex` feature is a string and not a numerical value. So, instead of looking at the whole dataframe as extracted from the dataset, let's first create a new dataframe with numerical values for `Sex`, and remove some unnecessary features (like `PassengerId`).

# %%
df2 = df

# Drop unnecessary features for correlation
df2 = df2.drop(['PassengerId', 'Name', 'Ticket', 'Cabin'], axis = 1)

# Create numerical values for string features
df2 = df2.replace({
                    'Sex': {'male': 0, 'female': 1},
                    'Embarked': {'S': 0, 'Q': 1, 'C': 2}
                  })

df2.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0         0       3    0  22.0      1      0   7.2500       0.0
# 1         1       1    1  38.0      1      0  71.2833       2.0
# 2         1       3    1  26.0      0      0   7.9250       0.0
# 3         1       1    1  35.0      1      0  53.1000       0.0
# 4         0       3    0  35.0      0      0   8.0500       0.0

# %%
df2.corr()
# Out:
#           Survived    Pclass       Sex       Age     SibSp     Parch  \
# Survived  1.000000 -0.338481  0.543351 -0.077221 -0.035322  0.081629
# Pclass   -0.338481  1.000000 -0.131900 -0.369226  0.083081  0.018443
# Sex       0.543351 -0.131900  1.000000 -0.093254  0.114631  0.245489
# Age      -0.077221 -0.369226 -0.093254  1.000000 -0.308247 -0.189119
# SibSp    -0.035322  0.083081  0.114631 -0.308247  1.000000  0.414838
# Parch     0.081629  0.018443  0.245489 -0.189119  0.414838  1.000000
# Fare      0.257307 -0.549500  0.182333  0.096067  0.159651  0.216225
# Embarked  0.169718 -0.164681  0.110320  0.032565 -0.068900 -0.040449
#
#               Fare  Embarked
# Survived  0.257307  0.169718
# Pclass   -0.549500 -0.164681
# Sex       0.182333  0.110320
# Age       0.096067  0.032565
# SibSp     0.159651 -0.068900
# Parch     0.216225 -0.040449
# Fare      1.000000  0.226311
# Embarked  0.226311  1.000000

# %% [markdown]
# Now we have a better idea on what features the `Survived` attribute directly depends on.

# %%
df2.corr().Survived
# Out:
# Survived    1.000000
# Pclass     -0.338481
# Sex         0.543351
# Age        -0.077221
# SibSp      -0.035322
# Parch       0.081629
# Fare        0.257307
# Embarked    0.169718
# Name: Survived, dtype: float64

# %% [markdown]
# The passenger survival is more demendant on the passenger class `Pclass`, the ticket fare `Fare` and the passenger sex. The correlation shows what variables directly affect the survival.

# %% [markdown]
# ***
# In the next chapter, we will clean data before creating classifiers.
